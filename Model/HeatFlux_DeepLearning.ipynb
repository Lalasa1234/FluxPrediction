# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.metrics import mean_squared_error
import category_encoders as ce
from sklearn.preprocessing import normalize

import torch
import torch.nn as nn
from torch.nn import Linear, ReLU, Sequential, Dropout
import torch.optim as optim
# pytorch needs data in as a Dataset obj to train and evaluate models
# when dataset is wrapped, it is called DataLoader that parallelly trains the model based on batches
from torch.utils.data import Dataset,DataLoader

import optuna
from optuna.trial import TrialState
import joblib
# not using optuna.visualization direclly due to image rendering issues

# %%
EPOCHS = 100
SEED = 42
BATCH = 32

# %% [markdown]
# **Problem Statement**
#
# Flux means flow, critical heat flux is that limit beyond which heat can no longer flow from the solid to the liquid. At this point, vapour starts getting formed. Operating the system beyond this limit leads to overheating and failure. Hence predicting this value becomes important.

# %% [markdown]
# **Data Visualization Insights**
#
# Output is higher for plate geometries (small length and high D_h)
#
# D_e and D_h impact pressure in a similar way
#
# chf_exp dist. is slightly right-skewed
#
# xeout negatively co-relates to output (-.5)

# %% [markdown]
# **Splitting into train and test data**

# %%
# Encoding can be done as a part of preprocessing
df = pd.read_csv(r"C:\Users\Dell\Desktop\ML course\CriticalHeatFluxPrediction_Project5\Dataset\FinalDataset.csv")
df
# Out:
#             author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0          Inasaka     tube            0.39                 5600      -0.1041
# 1          Inasaka     tube            0.31                 6700      -0.0596
# 2          Inasaka     tube            0.33                 4300      -0.0395
# 3          Inasaka     tube            0.62                 6400      -0.1460
# 4          Inasaka     tube            0.64                 4700      -0.0849
# ...            ...      ...             ...                  ...          ...
# 1811  Richenderfer    plate            1.01                 1500      -0.0218
# 1812  Richenderfer    plate            1.01                 1500      -0.0434
# 1813  Richenderfer    plate            1.01                 2000      -0.0109
# 1814  Richenderfer    plate            1.01                 2000      -0.0218
# 1815  Richenderfer    plate            1.01                 2000      -0.0434
#
#       D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0          3.0       3.0          100             11.3
# 1          3.0       3.0          100             10.6
# 2          3.0       3.0          100              7.3
# 3          3.0       3.0          100             12.8
# 4          3.0       3.0          100             11.0
# ...        ...       ...          ...              ...
# 1811      15.0     120.0           10              9.4
# 1812      15.0     120.0           10             10.4
# 1813      15.0     120.0           10             10.8
# 1814      15.0     120.0           10             10.9
# 1815      15.0     120.0           10             11.5
#
# [1816 rows x 9 columns]

# %%
X = df.drop(columns =['chf_exp [MW/m2]'])
y = df['chf_exp [MW/m2]']

# %%
# Understand the distribution of chf
plt.scatter(y, range(len(y)))

# %%
encode = ce.OrdinalEncoder()
X_encoded = encode.fit_transform(X)

# %%
# shuffling the data is preferred when the samples are ordered before getting split, shuffle is True by default
X_train, X_test, y_train, y_test = train_test_split(X_encoded,y,test_size = 0.2, random_state=SEED)

# %%
# there are 2 outliers between 14 and 16, ultimately model should be able to predict beyond 15 (in test) as well
plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.hist(y_train)

plt.subplot(1,2,2)
plt.hist(y_test)
# Out:
# (array([117., 153.,  63.,  23.,   4.,   1.,   2.,   0.,   0.,   1.]),
#  array([ 0.9 ,  2.74,  4.58,  6.42,  8.26, 10.1 , 11.94, 13.78, 15.62,
#         17.46, 19.3 ]),
#  <BarContainer object of 10 artists>)

# %%
# Normalizing only the input
X_new_train = normalize(X_train)
X_new_test = normalize(X_test)
print (X_new_train.shape, X_new_test.shape, y_train.shape, y_test.shape)
X_new_train
# Out:
# (1452, 8) (364, 8) (1452,) (364,)
# array([[1.65267750e-03, 5.50892499e-04, 3.74056007e-03, ...,
#         5.94963899e-03, 5.94963899e-03, 2.37985559e-01],
#        [1.41329526e-03, 4.71098420e-04, 3.65336825e-03, ...,
#         1.31907558e-03, 3.58034799e-03, 5.02662014e-01],
#        [2.34983740e-03, 6.71382115e-04, 2.31291139e-03, ...,
#         4.26327643e-03, 1.41997317e-02, 9.20800571e-01],
#        ...,
#        [6.03112074e-04, 2.01037358e-04, 2.77230517e-03, ...,
#         9.44875582e-04, 9.44875582e-04, 6.39298798e-02],
#        [2.37701961e-03, 7.92339869e-04, 3.27632536e-03, ...,
#         2.21855163e-03, 6.02178301e-03, 8.45426640e-01],
#        [1.36241925e-03, 4.54139751e-04, 7.82936930e-03, ...,
#         8.62865526e-04, 8.62865526e-04, 3.16081266e-01]])

# %%
# tensor is a numpy array that allows backpropagation
# requires_grad = True. Technical: for autograd to record operations on tensor, Simplied: whether trainable or not
# About autograd: it results in a acyclic graph which input tensors as leaves, and output tensors as root. One can calcuate the gradient (of loss func.) from leaf to root.
def convert_to_torch(val):
    return torch.tensor(data = val,dtype = torch.float,requires_grad=True)

# %%
# torch in general either takes a df or a single column array, not a series
X_new_train = convert_to_torch(X_new_train)
X_new_test = convert_to_torch(X_new_test)
y_new_train = convert_to_torch(y_train).reshape(-1,1)
y_new_test = convert_to_torch(y_test.to_numpy()).reshape(-1,1)
print (type(y_new_train), y_new_test.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([364, 1])

# %%
# Inherit the Dataset class properties and override getitem and len
# DataLoader needs to know the no. of examples created in the dataset, hence __len__
class FluxDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx],self.y[idx]

# %%
train_data = FluxDataset(X_new_train, y_new_train)
test_data = FluxDataset(X_new_test, y_new_test)

# %%
# Shuffle for train set, not needed for test
train_loader = DataLoader(train_data,batch_size=BATCH,shuffle=True)
test_loader = DataLoader(test_data,batch_size=BATCH, shuffle = False)

#Size of the loader is the size of train_data/32 as it has been divided into batches
#Benefit: Model trains faster when in batches, hence DataLoader allows us to divide dataset into batches
print (len(train_data), len(train_loader))
# Out:
# 1452 46

# %% [markdown]
# **Defining the Custom Model, Training and Evaluating it**

# %%
class FluxModel(nn.Module):
    def __init__(self, n_features):
        # define all parts of the model
        # Xavier and Kaiming are useful to limit output, for classification but not regression (here)
        super().__init__()
        self.layer1 = Linear(n_features, 24)
        self.act1 = ReLU()
        self.drop1 = Dropout(0.2)
        self.layer2 = Linear(24,12)
        self.act2 = ReLU()
        self.drop2 = Dropout(0.2)
        # self.layer3 = Linear(12,6)
        # self.act3 = ReLU()
        # self.drop3 = Dropout(0.2)
        self.output = Linear(12,1)

    # take a batch of examples x,connect them and return the output
    def forward(self,x):
        x = self.layer1(x)
        x = self.act1(x)
        x = self.drop1(x)
        x = self.layer2(x)
        x = self.act2(x)
        x = self.drop2(x)
        # x = self.layer3(x)
        # x = self.act3(x)
        # x = self.drop3(x)
        x = self.output(x)
        return x

# %%
# Define the training function
def train_model (train_dl, model):
    model.train()
    for epochs in range(EPOCHS*3):
        for i, (X,y) in enumerate(train_dl):
            X, y = X.float(), y.float()
            optimizer.zero_grad()
            y_pred = model(X)
            loss = loss_fn(y_pred, y)
            loss.backward()
            optimizer.step()

# %%
# Define the eval function
def eval_model (test_dl, model):
    predictions, actuals = [],[]
    model.eval()
    with torch.no_grad():
        for i, (X,y) in enumerate(test_dl):
            X , y = X.float(), y.float()
            y_pred = model(X)
            loss = loss_fn (y_pred, y)
            y_pred = y_pred.detach().numpy()
            predictions.append(y_pred)
            actuals.append(y)
    # vstack creates a stack of each array item row-wise
    predictions , actuals = np.vstack(predictions), np.vstack(actuals)
    
    # calculate mse
    mse = mean_squared_error(actuals, predictions)
    return mse, actuals, predictions

# %%
# define the prediction function for a single sample row
def pred(samp, model):
    samp = torch.Tensor(samp)
    y_pred = model(samp)
    return y_pred.item()

# %%
# Initialize and train the model
model = FluxModel(8)
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001, weight_decay=0.001)
train_model(train_loader, model)

# %%
# Evaluate the model
mse, actuals, predictions = eval_model(test_loader, model)
print (f'Overall rmse is {np.sqrt(mse)}')
plt.scatter(predictions, range(len(predictions)), color = 'red')
plt.scatter(actuals, range(len(actuals)), color = 'blue')
plt.legend(['Predictions', 'Actuals'])

#Overall rmse is 1.26600182056427
# Out:
# Overall rmse is 1.3868948221206665

# %% [markdown]
# # Baseline Modeling and Experimentation:
# CURRENT: Epochs = 100, dropin at input of 0.2, adam lr = 0.001: rmse = 1.5
#
# - Increase epochs to 200, gave 1.4 and a much better plot
# - Epochs to 300, gave 1.3, with a slightly better plot, predicting up to 8
# - Increase lr to 0.005, gave 1.31
# - adding weight_decay (=L2 penalty) (default 0) of 0.001 (= lr), rmse = 1.33, plot has degraded slightly

# %% [markdown]
# ## Optuna-based Hyperparameter Tuning ##

# %%
# https://blog.paperspace.com/svr-kmeans-clustering-for-regression/

# %%
def optuna_model(trial):
    n_features = 8
    n_layers = trial.suggest_int('n_layers', 2, 4)
    layers = []
    for i in range(n_layers):
        o_layer = trial.suggest_int('o_layer {}'.format(i+1),8,24)
        layers.append(Linear(n_features,o_layer))
        layers.append(ReLU())
        p = trial.suggest_float('drop_layer '.format(i+1),0.0,0.2,step = 0.01)
        layers.append(Dropout(p))
        n_features = o_layer

    layers.append(Linear(n_features,1))
    return Sequential(*layers)

# %%
def optuna_train_model (trial, train_dl, test_dl, model):
    loss_fn = nn.MSELoss()
    model.train()
    for epochs in range(EPOCHS*3):
        for i, (X,y) in enumerate(train_dl):
            X, y = X.float(), y.float()
            optimizer.zero_grad()
            y_pred = model(X)
            loss = loss_fn(y_pred, y)
            loss.backward()
            optimizer.step()

        predictions, actuals = [],[]
        model.eval()
        with torch.no_grad():
            for i, (X,y) in enumerate(test_dl):
                X , y = X.float(), y.float()
                y_pred = model(X)
                y_pred = y_pred.detach().numpy()
                predictions.append(y_pred)
                actuals.append(y)
            predictions, actuals = np.vstack(predictions), np.vstack(actuals)
                
        mse = mean_squared_error(actuals, predictions)
        trial.report(mse,epochs)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        return mse

# %%
def objective(trial):
    model = optuna_model(trial)
    # log = True means logarithmic value
    lr = trial.suggest_float('lr',0.001,0.01, log = True)
    optimizer = optim.Adam(model.parameters(), lr = lr)
    test_mse = optuna_train_model(trial, train_loader, test_loader, model)
    return test_mse

# %%
# create_study(sampler = TPESampler) TPESampler is the default for single obj.
study = optuna.create_study(direction = 'minimize')
study.optimize(objective, n_trials = 100, timeout = 600)
# Out:
# [I 2024-06-13 11:32:06,214] A new study created in memory with name: no-name-b7b7a9f1-ed32-4c11-8604-df8d2face092
# [I 2024-06-13 11:32:06,537] Trial 0 finished with value: 18.742143630981445 and parameters: {'n_layers': 2, 'o_layer 1': 8, 'drop_layer ': 0.19, 'o_layer 2': 17, 'lr': 0.001363910022962017}. Best is trial 0 with value: 18.742143630981445.
# [I 2024-06-13 11:32:06,936] Trial 1 finished with value: 19.67352294921875 and parameters: {'n_layers': 4, 'o_layer 1': 17, 'drop_layer ': 0.13, 'o_layer 2': 9, 'o_layer 3': 11, 'o_layer 4': 23, 'lr': 0.0019381079401505988}. Best is trial 0 with value: 18.742143630981445.
# [I 2024-06-13 11:32:07,341] Trial 2 finished with value: 20.306751251220703 and parameters: {'n_layers': 4, 'o_layer 1': 16, 'drop_layer ': 0.01, 'o_layer 2': 21, 'o_layer 3': 13, 'o_layer 4': 10, 'lr': 0.0017947525403626968}. Best is trial 0 with value: 18.742143630981445.
# [I 2024-06-13 11:32:07,732] Trial 3 finished with value: 17.16021728515625 and parameters: {'n_layers': 3, 'o_layer 1': 23, 'drop_layer ': 0.01, 'o_layer 2': 18, 'o_layer 3': 15, 'lr': 0.002363233993760643}. Best is trial 3 with value: 17.16021728515625.
# [I 2024-06-13 11:32:08,080] Trial 4 finished with value: 17.106008529663086 and parameters: {'n_layers': 3, 'o_layer 1': 21, 'drop_layer ': 0.07, 'o_layer 2': 15, 'o_layer 3': 12, 'lr': 0.0018078354781455802}. Best is trial 4 with value: 17.106008529663086.
# [I 2024-06-13 11:32:08,465] Trial 5 finished with value: 17.69702911376953 and parameters: {'n_layers': 3, 'o_layer 1': 20, 'drop_layer ': 0.16, 'o_layer 2': 24, 'o_layer 3': 20, 'lr': 0.0069776183149133295}. Best is trial 4 with value: 17.106008529663086.
# [I 2024-06-13 11:32:08,797] Trial 6 finished with value: 17.44847869873047 and parameters: {'n_layers': 4, 'o_layer 1': 24, 'drop_layer ': 0.14, 'o_layer 2': 23, 'o_layer 3': 10, 'o_layer 4': 18, 'lr': 0.007382444845270543}. Best is trial 4 with value: 17.106008529663086.
# [I 2024-06-13 11:32:09,211] Trial 7 finished with value: 17.53569221496582 and parameters: {'n_layers': 4, 'o_layer 1': 15, 'drop_layer ': 0.09, 'o_layer 2': 15, 'o_layer 3': 24, 'o_layer 4': 22, 'lr': 0.0022047442423702756}. Best is trial 4 with value: 17.106008529663086.
# [I 2024-06-13 11:32:09,562] Trial 8 finished with value: 16.784908294677734 and parameters: {'n_layers': 2, 'o_layer 1': 24, 'drop_layer ': 0.19, 'o_layer 2': 22, 'lr': 0.004068321409468881}. Best is trial 8 with value: 16.784908294677734.
# [I 2024-06-13 11:32:09,953] Trial 9 pruned.
# [I 2024-06-13 11:32:10,468] Trial 10 finished with value: 16.681655883789062 and parameters: {'n_layers': 2, 'o_layer 1': 10, 'drop_layer ': 0.2, 'o_layer 2': 11, 'lr': 0.004192630908149443}. Best is trial 10 with value: 16.681655883789062.
# [I 2024-06-13 11:32:10,908] Trial 11 pruned.
# [I 2024-06-13 11:32:11,457] Trial 12 pruned.
# [I 2024-06-13 11:32:11,794] Trial 13 finished with value: 17.018407821655273 and parameters: {'n_layers': 2, 'o_layer 1': 12, 'drop_layer ': 0.17, 'o_layer 2': 12, 'lr': 0.0051058214100431374}. Best is trial 10 with value: 16.681655883789062.
# [I 2024-06-13 11:32:12,246] Trial 14 pruned.
# [I 2024-06-13 11:32:12,729] Trial 15 finished with value: 16.74161148071289 and parameters: {'n_layers': 3, 'o_layer 1': 12, 'drop_layer ': 0.05, 'o_layer 2': 12, 'o_layer 3': 19, 'lr': 0.009582293815654766}. Best is trial 10 with value: 16.681655883789062.
# [I 2024-06-13 11:32:13,191] Trial 16 pruned.
# [I 2024-06-13 11:32:13,609] Trial 17 pruned.
# [I 2024-06-13 11:32:14,031] Trial 18 pruned.
# [I 2024-06-13 11:32:14,531] Trial 19 finished with value: 16.411291122436523 and parameters: {'n_layers': 3, 'o_layer 1': 14, 'drop_layer ': 0.09, 'o_layer 2': 14, 'o_layer 3': 8, 'lr': 0.002972570494816263}. Best is trial 19 with value: 16.411291122436523.
# [I 2024-06-13 11:32:14,999] Trial 20 pruned.
# [I 2024-06-13 11:32:15,504] Trial 21 pruned.
# [I 2024-06-13 11:32:16,046] Trial 22 pruned.
# [I 2024-06-13 11:32:16,539] Trial 23 pruned.
# [I 2024-06-13 11:32:16,922] Trial 24 pruned.
# [I 2024-06-13 11:32:17,380] Trial 25 pruned.
# [I 2024-06-13 11:32:17,870] Trial 26 pruned.
# [I 2024-06-13 11:32:18,389] Trial 27 pruned.
# [I 2024-06-13 11:32:18,884] Trial 28 pruned.
# [I 2024-06-13 11:32:19,287] Trial 29 pruned.
# [I 2024-06-13 11:32:19,652] Trial 30 pruned.
# [I 2024-06-13 11:32:20,051] Trial 31 pruned.
# [I 2024-06-13 11:32:20,421] Trial 32 finished with value: 16.387161254882812 and parameters: {'n_layers': 2, 'o_layer 1': 14, 'drop_layer ': 0.19, 'o_layer 2': 11, 'lr': 0.003950392039964624}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:20,844] Trial 33 pruned.
# [I 2024-06-13 11:32:21,191] Trial 34 finished with value: 16.835895538330078 and parameters: {'n_layers': 2, 'o_layer 1': 13, 'drop_layer ': 0.13, 'o_layer 2': 10, 'lr': 0.008251481698129748}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:21,565] Trial 35 pruned.
# [I 2024-06-13 11:32:21,933] Trial 36 pruned.
# [I 2024-06-13 11:32:22,278] Trial 37 pruned.
# [I 2024-06-13 11:32:22,792] Trial 38 pruned.
# [I 2024-06-13 11:32:23,345] Trial 39 pruned.
# [I 2024-06-13 11:32:23,934] Trial 40 pruned.
# [I 2024-06-13 11:32:24,374] Trial 41 pruned.
# [I 2024-06-13 11:32:24,801] Trial 42 pruned.
# [I 2024-06-13 11:32:25,268] Trial 43 finished with value: 16.669164657592773 and parameters: {'n_layers': 2, 'o_layer 1': 15, 'drop_layer ': 0.15, 'o_layer 2': 13, 'lr': 0.002966232074027569}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:25,800] Trial 44 pruned.
# [I 2024-06-13 11:32:26,312] Trial 45 pruned.
# [I 2024-06-13 11:32:26,808] Trial 46 pruned.
# [I 2024-06-13 11:32:27,276] Trial 47 finished with value: 16.776060104370117 and parameters: {'n_layers': 2, 'o_layer 1': 12, 'drop_layer ': 0.14, 'o_layer 2': 12, 'lr': 0.003100913338618022}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:27,774] Trial 48 pruned.
# [I 2024-06-13 11:32:28,325] Trial 49 pruned.
# [I 2024-06-13 11:32:28,906] Trial 50 finished with value: 16.446290969848633 and parameters: {'n_layers': 3, 'o_layer 1': 11, 'drop_layer ': 0.1, 'o_layer 2': 11, 'o_layer 3': 9, 'lr': 0.008745882350126251}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:29,428] Trial 51 pruned.
# [I 2024-06-13 11:32:29,898] Trial 52 pruned.
# [I 2024-06-13 11:32:30,396] Trial 53 pruned.
# [I 2024-06-13 11:32:30,906] Trial 54 pruned.
# [I 2024-06-13 11:32:31,341] Trial 55 finished with value: 16.478687286376953 and parameters: {'n_layers': 2, 'o_layer 1': 13, 'drop_layer ': 0.08, 'o_layer 2': 11, 'lr': 0.006731887264213085}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:31,801] Trial 56 finished with value: 16.649873733520508 and parameters: {'n_layers': 2, 'o_layer 1': 13, 'drop_layer ': 0.08, 'o_layer 2': 8, 'lr': 0.004934685083196304}. Best is trial 32 with value: 16.387161254882812.
# [I 2024-06-13 11:32:32,184] Trial 57 pruned.
# [I 2024-06-13 11:32:32,651] Trial 58 finished with value: 15.966693878173828 and parameters: {'n_layers': 2, 'o_layer 1': 14, 'drop_layer ': 0.07, 'o_layer 2': 9, 'lr': 0.00588294016015531}. Best is trial 58 with value: 15.966693878173828.
# [I 2024-06-13 11:32:33,107] Trial 59 pruned.
# [I 2024-06-13 11:32:33,518] Trial 60 pruned.
# [I 2024-06-13 11:32:33,928] Trial 61 pruned.
# [I 2024-06-13 11:32:34,401] Trial 62 finished with value: 15.93606185913086 and parameters: {'n_layers': 2, 'o_layer 1': 16, 'drop_layer ': 0.07, 'o_layer 2': 10, 'lr': 0.00729120207388903}. Best is trial 62 with value: 15.93606185913086.
# [I 2024-06-13 11:32:34,847] Trial 63 pruned.
# [I 2024-06-13 11:32:35,311] Trial 64 pruned.
# [I 2024-06-13 11:32:35,740] Trial 65 finished with value: 16.306848526000977 and parameters: {'n_layers': 2, 'o_layer 1': 18, 'drop_layer ': 0.05, 'o_layer 2': 9, 'lr': 0.006815784921857581}. Best is trial 62 with value: 15.93606185913086.
# [I 2024-06-13 11:32:36,250] Trial 66 pruned.
# [I 2024-06-13 11:32:36,716] Trial 67 pruned.
# [I 2024-06-13 11:32:37,260] Trial 68 pruned.
# [I 2024-06-13 11:32:37,767] Trial 69 pruned.
# [I 2024-06-13 11:32:38,215] Trial 70 pruned.
# [I 2024-06-13 11:32:38,790] Trial 71 pruned.
# [I 2024-06-13 11:32:39,228] Trial 72 pruned.
# [I 2024-06-13 11:32:39,691] Trial 73 pruned.
# [I 2024-06-13 11:32:40,072] Trial 74 pruned.
# [I 2024-06-13 11:32:40,481] Trial 75 finished with value: 16.468446731567383 and parameters: {'n_layers': 2, 'o_layer 1': 11, 'drop_layer ': 0.09, 'o_layer 2': 8, 'lr': 0.0047588418733407085}. Best is trial 62 with value: 15.93606185913086.
# [I 2024-06-13 11:32:41,023] Trial 76 pruned.
# [I 2024-06-13 11:32:41,488] Trial 77 pruned.
# [I 2024-06-13 11:32:42,030] Trial 78 pruned.
# [I 2024-06-13 11:32:42,541] Trial 79 pruned.
# [I 2024-06-13 11:32:43,087] Trial 80 pruned.
# [I 2024-06-13 11:32:43,518] Trial 81 pruned.
# [I 2024-06-13 11:32:43,998] Trial 82 pruned.
# [I 2024-06-13 11:32:44,436] Trial 83 finished with value: 16.564573287963867 and parameters: {'n_layers': 2, 'o_layer 1': 10, 'drop_layer ': 0.07, 'o_layer 2': 9, 'lr': 0.0037155094224535267}. Best is trial 62 with value: 15.93606185913086.
# [I 2024-06-13 11:32:44,841] Trial 84 finished with value: 16.391286849975586 and parameters: {'n_layers': 2, 'o_layer 1': 10, 'drop_layer ': 0.06, 'o_layer 2': 9, 'lr': 0.003263133852335093}. Best is trial 62 with value: 15.93606185913086.
# [I 2024-06-13 11:32:45,292] Trial 85 finished with value: 15.615643501281738 and parameters: {'n_layers': 2, 'o_layer 1': 9, 'drop_layer ': 0.05, 'o_layer 2': 10, 'lr': 0.0040778462293103645}. Best is trial 85 with value: 15.615643501281738.
# [I 2024-06-13 11:32:45,671] Trial 86 pruned.
# [I 2024-06-13 11:32:46,118] Trial 87 pruned.
# [I 2024-06-13 11:32:46,686] Trial 88 finished with value: 16.428735733032227 and parameters: {'n_layers': 3, 'o_layer 1': 10, 'drop_layer ': 0.03, 'o_layer 2': 10, 'o_layer 3': 9, 'lr': 0.004002211633649662}. Best is trial 85 with value: 15.615643501281738.
# [I 2024-06-13 11:32:47,327] Trial 89 pruned.
# [I 2024-06-13 11:32:47,804] Trial 90 pruned.
# [I 2024-06-13 11:32:48,402] Trial 91 pruned.
# [I 2024-06-13 11:32:48,942] Trial 92 pruned.
# [I 2024-06-13 11:32:49,499] Trial 93 pruned.
# [I 2024-06-13 11:32:49,961] Trial 94 pruned.
# [I 2024-06-13 11:32:50,493] Trial 95 pruned.
# [I 2024-06-13 11:32:51,141] Trial 96 pruned.
# [I 2024-06-13 11:32:51,596] Trial 97 pruned.
# [I 2024-06-13 11:32:52,120] Trial 98 pruned.
# [I 2024-06-13 11:32:52,638] Trial 99 pruned.

# %%
pruned_trials = study.get_trials(deepcopy = False, states = [TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy = False, states = [TrialState.COMPLETE])

print ('Study statistics')
print (f'No of total trials is {len(study.trials)}')
print (f'Pruned trials are {len(pruned_trials)} and Completed trials are {len(complete_trials)}')
print(f'The best trial gives an with rmse of {np.sqrt(study.best_trial.value)}')
print (f'The best parameter values are:')
for key, value in study.best_trial.params.items():
    print (f'{key}: {value}')
# Out:
# Study statistics
# No of total trials is 100
# Pruned trials are 72 and Completed trials are 28
# The best trial gives an with rmse of 3.951663384105703
# The best parameter values are:
# n_layers: 2
# o_layer 1: 9
# drop_layer : 0.05
# o_layer 2: 10
# lr: 0.0040778462293103645

# %% [markdown]
# **Build the model with tuned values**

# %%
class BestModel(nn.Module):
    def __init__(self, n_features):
        super().__init__()
        self.layer1 = Linear(n_features, 9)
        self.act1 = ReLU()
        self.drop1 = Dropout(0.15)
        self.layer2 = Linear(9,13)
        self.act2 = ReLU()
        # self.drop2 = Dropout(0.2)
        self.layer3 = Linear(13,11)
        self.act3 = ReLU()
        # self.drop3 = Dropout(0.1)
        self.output = Linear(11,1)

    def forward(self,x):
        x = self.layer1(x)
        x = self.act1(x)
        x = self.drop1(x)
        x = self.layer2(x)
        x = self.act2(x)
        # x = self.drop2(x)
        x = self.layer3(x)
        x = self.act3(x)
        # x = self.drop3(x)
        x = self.output(x)
        return x

# %%
model = BestModel(8)
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.0013)
train_model(train_loader, model)

# %%
mse, actuals, predictions = eval_model(test_loader, model)
print (f'Overall rmse is {np.sqrt(mse)}')
plt.scatter(predictions, range(len(predictions)), color = 'red')
plt.scatter(actuals, range(len(actuals)), color = 'blue')
plt.legend(['Predictions', 'Actuals'])
# Out:
# Overall rmse is 1.3438800573349

# %%
# Predicting over a sample
print (f'Overall rmse is {np.sqrt(mse)}')
pred_mse = pred([3.5722e-03, 8.9305e-04, 4.9252e-03, 3.0319e-01, 9.9352e-05, 2.2326e-03,
        5.9388e-03, 9.5289e-01],model)
print (f'rmse of the sample is {np.sqrt(pred_mse)}')
# Out:
# Overall rmse is 1.3438800573349
# rmse of the sample is 1.499382686746348

# %% [markdown]
# **Optuna Visualizations**

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\1455980257.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study)
# <Axes: title={'center': 'Optimization History Plot'}, xlabel='Trial', ylabel='Objective Value'>

# %%
# based on the plot, Adam has performed the best with decreasing objective values
optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["o_layer 2"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\2082283104.py:2: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["o_layer 2"])
# <Axes: title={'center': 'Parallel Coordinate Plot'}>

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["o_layer 3"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\1678582933.py:1: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["o_layer 3"])
# <Axes: title={'center': 'Parallel Coordinate Plot'}>

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["n_layers"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\2937014235.py:1: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["n_layers"])
# <Axes: title={'center': 'Parallel Coordinate Plot'}>

# %%
optuna.visualization.matplotlib.plot_slice(study)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\2375574420.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_slice(study)
# array([<Axes: xlabel='drop_layer ', ylabel='Objective Value'>,
#        <Axes: xlabel='lr'>, <Axes: xlabel='n_layers'>,
#        <Axes: xlabel='o_layer 1'>, <Axes: xlabel='o_layer 2'>,
#        <Axes: xlabel='o_layer 3'>, <Axes: xlabel='o_layer 4'>],
#       dtype=object)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19316\1036994904.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %% [markdown]
# ## Saving the Model ##

# %%
torch.save(model.state_dict(),r'C:\Users\Dell\Desktop\ML course\CriticalHeatFluxPrediction_Project5\Model\TorchModel.pt')

# %%
model_state = torch.load(r'C:\Users\Dell\Desktop\ML course\CriticalHeatFluxPrediction_Project5\Model\TorchModel.pt')
model_state
# Out:
# OrderedDict([('layer1.weight',
#               tensor([[ 6.6597e-01,  3.1382e-01, -7.0337e+00,  2.3999e-01, -1.5254e+01,
#                         3.3073e+00,  1.3461e+00, -1.5007e-01],
#                       [-1.3791e+00, -1.4733e+00, -8.0186e+00, -2.4147e-01, -1.3983e+01,
#                         1.2083e+00, -3.7696e-01, -1.9026e-01],
#                       [-3.4103e-01, -2.0267e-01,  2.5967e-02, -2.4750e-01,  3.4063e-02,
#                        -9.1612e-02, -1.2915e-01, -3.0952e-01],
#                       [-2.2153e+00, -1.5076e+00, -7.4234e+00, -3.3763e-02, -1.1817e+01,
#                        -2.8226e-01, -2.4891e-01, -9.0250e-01],
#                       [-1.9304e+00, -2.1642e+00, -7.7559e+00,  1.7838e-01, -1.3656e+01,
#                         1.4403e-01, -1.3661e-01, -1.3456e-01],
#                       [-2.1479e+00, -1.8657e+00, -7.5760e+00,  1.4817e-01, -1.3065e+01,
#                         1.9997e-01, -1.1467e-01, -1.0080e-01],
#                       [-1.7764e+00, -1.5772e+00, -7.7921e+00,  5.6148e-02, -1.4689e+01,
#                         1.4549e+00, -3.1929e-01, -5.9058e-01],
#                       [ 3.1549e-01, -1.0301e-01, -1.3705e-01, -2.2722e-01, -1.3484e-01,
#                        -1.1627e-01, -3.4769e-01, -3.0802e-01],
#                       [-2.2450e+00, -1.6125e+00, -7.4023e+00, -1.3837e-01, -1.1639e+01,
#                        -1.2399e-02, -2.1228e-01, -8.7183e-01]])),
#              ('layer1.bias',
#               tensor([ 0.2851,  0.3073,  0.1928,  0.2251, -0.1259, -0.0920,  0.1697, -0.1965,
#                        0.2156])),
#              ('layer2.weight',
#               tensor([[ 0.0840,  1.1063, -0.0119,  0.9097,  1.0957,  0.9196,  0.0466, -0.2628,
#                         0.8024],
#                       [ 0.2497,  0.5522,  0.3563,  0.8171,  1.1280,  1.2244, -0.2154, -0.1452,
#                         1.2306],
#                       [ 0.1184,  0.1685,  0.1346, -0.0360,  0.0984, -0.0986, -0.1701, -0.2261,
#                        -0.3733],
#                       [ 0.0730,  0.7988, -0.1535,  0.4345,  1.0991,  0.9270,  0.2473, -0.3120,
#                         1.3121],
#                       [ 0.0653,  0.0242,  0.1509, -0.0086, -0.2031, -0.1622, -0.2934, -0.1993,
#                         0.1730],
#                       [-0.1006, -0.0617, -0.0623, -0.2358,  0.0103,  0.1667,  0.1116,  0.2023,
#                        -0.0852],
#                       [-0.6419,  0.0238, -0.3284,  0.5239,  0.3089,  0.1828,  0.6418, -0.1926,
#                         0.6858],
#                       [-0.2174,  0.9322,  0.1352,  0.8941,  0.7786,  0.5657, -0.0095,  0.2865,
#                         1.6042],
#                       [ 0.4709,  1.0487, -0.2512,  0.6738,  1.0807,  0.8007,  0.0406, -0.2702,
#                         1.4109],
#                       [-0.1812,  0.0258, -0.3033, -0.2476, -0.1807,  0.1278, -0.1164,  0.3034,
#                         0.1142],
#                       [ 0.0368,  1.0638, -0.2676, -1.6407,  0.8662,  0.7698,  0.5320, -0.2882,
#                         0.0354],
#                       [ 0.1750,  0.7308, -0.0967,  0.8758,  1.1536,  0.8326,  0.3588,  0.0566,
#                         1.0512],
#                       [ 0.4627,  0.8619,  0.0903,  0.5240,  1.2241,  0.9698,  0.0946, -0.1314,
#                         1.3063]])),
#              ('layer2.bias',
#               tensor([ 0.3857,  0.0327, -0.3854,  0.1117, -0.2678, -0.1617,  0.1345,  0.1032,
#                       -0.1003, -0.0873, -0.0035,  0.4026, -0.1152])),
#              ('layer3.weight',
#               tensor([[-2.1122e-01,  1.1901e-01, -6.3040e-02, -1.0730e-01, -2.3609e-01,
#                         1.9309e-01,  2.0173e-01, -7.5228e-02, -1.1448e-01, -1.1010e-01,
#                         2.0597e-01,  2.4318e-01, -1.5841e-01],
#                       [ 6.2379e-01,  9.2611e-01, -5.5305e-02,  3.2586e-01,  4.5643e-02,
#                        -1.1410e-01,  1.3102e+00,  1.3923e+00,  8.1439e-01,  3.5394e-01,
#                         2.8119e+00,  1.5171e-01,  6.5343e-01],
#                       [ 1.6142e-01, -2.4666e-01, -3.6133e-02, -2.6294e-01,  2.5792e-02,
#                        -2.7920e-01, -1.6542e+00, -6.6112e-01, -5.6722e-01,  1.0640e-01,
#                        -7.3814e-01,  1.9321e-01, -5.2165e-01],
#                       [-2.6369e-01,  9.2454e-02,  2.5572e-01,  5.2727e-02, -1.3690e-01,
#                         2.6878e-01, -2.5926e-02,  4.3645e-02,  2.1681e-01,  2.5378e-01,
#                        -1.7829e-01, -7.4430e-02, -4.0217e-02],
#                       [-2.0246e-01, -8.3476e-04, -2.2270e-01,  9.1032e-02,  1.9032e-01,
#                         2.6955e-01, -2.0426e-01, -8.5160e-02, -2.7431e-01, -2.6065e-01,
#                        -3.5852e-03, -1.6627e-01,  2.6292e-01],
#                       [ 5.1859e-01,  8.3807e-01,  2.5852e-01,  3.1211e-01,  1.8277e-01,
#                         1.1024e-01,  8.4430e-01,  1.0551e+00,  7.3690e-01, -1.4423e-01,
#                         1.7051e+00,  3.8240e-01,  6.0920e-01],
#                       [ 2.6525e-02, -1.3688e-01, -5.1399e-02,  3.7061e-02, -3.0105e-02,
#                         6.5576e-02, -1.9291e-01,  1.2986e-01,  1.4501e-01,  2.0456e-01,
#                        -2.3413e-02, -1.1931e-01, -1.1436e-01],
#                       [-2.4752e-01,  5.2350e-02, -1.8904e-01,  1.0056e-01, -2.5666e-01,
#                         2.7564e-01,  2.1332e-01, -1.7641e-02, -2.3276e-01, -2.1358e-01,
#                        -1.4846e-01, -1.1255e-01, -8.3357e-02],
#                       [ 5.0718e-01,  5.9898e-01, -1.0481e-01,  7.2512e-01,  1.7121e-03,
#                        -4.3225e-02,  1.1267e+00,  1.3590e+00,  7.1140e-01,  1.7188e-02,
#                         1.7294e+00,  4.8376e-01,  6.1239e-01],
#                       [ 1.2840e-01, -1.8461e-01, -2.5297e-01, -2.4164e-01,  2.1901e-01,
#                        -8.2885e-02, -5.6770e-01, -1.2806e-01, -3.5228e-01,  7.7746e-03,
#                        -7.3687e-01,  2.5833e-01, -2.1951e-01],
#                       [ 3.3086e-01,  3.8414e-01, -1.3789e-01,  5.3677e-01,  2.4617e-01,
#                        -1.2166e-01,  1.1383e+00,  1.3184e+00,  3.1560e-01, -1.2201e-01,
#                         1.6749e+00,  4.9140e-01,  3.1135e-01]])),
#              ('layer3.bias',
#               tensor([-0.1037,  0.0658,  0.3438, -0.1922, -0.0665,  0.0891, -0.0440,  0.0429,
#                        0.1796,  0.1600,  0.2888])),
#              ('output.weight',
#               tensor([[-0.0911,  0.7763, -0.9643,  0.2899, -0.2301,  0.8632, -0.1135, -0.1537,
#                         0.7684, -0.4161,  0.8138]])),
#              ('output.bias', tensor([0.2726]))])

# %%
new_model = BestModel(8)

# %%
new_model.load_state_dict(model_state)
# Out:
# <All keys matched successfully>

# %%
new_model
# Out:
# BestModel(
#   (layer1): Linear(in_features=8, out_features=9, bias=True)
#   (act1): ReLU()
#   (drop1): Dropout(p=0.15, inplace=False)
#   (layer2): Linear(in_features=9, out_features=13, bias=True)
#   (act2): ReLU()
#   (layer3): Linear(in_features=13, out_features=11, bias=True)
#   (act3): ReLU()
#   (output): Linear(in_features=11, out_features=1, bias=True)
# )

# %%
new_model(X_new_test[0]).item()
# Out:
# 2.5227952003479004
